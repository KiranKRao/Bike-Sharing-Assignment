# %% [markdown]
# # Bike Sharing Assignment
# # Kiran Kumar Rao - 30 Dec 2021=4

# %%
# First Import the Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
warnings.filterwarnings('ignore')

# %%
#IMport file and load it in to a data frame
data = pd.read_csv("day.csv")

# %%
# Read first 10 record and see how data looks like
data.head(10)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        6           0
# 1        2  02-01-2018       1   0     1        0        0           0
# 2        3  03-01-2018       1   0     1        0        1           1
# 3        4  04-01-2018       1   0     1        0        2           1
# 4        5  05-01-2018       1   0     1        0        3           1
# 5        6  06-01-2018       1   0     1        0        4           1
# 6        7  07-01-2018       1   0     1        0        5           1
# 7        8  08-01-2018       1   0     1        0        6           0
# 8        9  09-01-2018       1   0     1        0        0           0
# 9       10  10-01-2018       1   0     1        0        1           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
# 5           1   8.378268  11.66045  51.8261   6.000868      88        1518
# 6           2   8.057402  10.44195  49.8696  11.304642     148        1362
# 7           2   6.765000   8.11270  53.5833  17.875868      68         891
# 8           1   5.671653   5.80875  43.4167  24.250650      54         768
# 9           1   6.184153   7.54440  48.2917  14.958889      41        1280
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
# 5  1606
# 6  1510
# 7   959
# 8   822
# 9  1321

# %%
data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
# Undertand the data
data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.465405    0.544807    7.506729    8.150308   14.237589    5.195841
# min      0.000000    1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      0.000000    1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000    1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      1.000000    2.000000   26.880615   30.445775   72.989575   15.625589
# max      1.000000    3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %%
# review the shape
data.shape
# Out:
# (730, 16)

# %%
# review the columns and its Data type
data.info()
# no null values found so we don't have to check null value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
#Data cleaning activty

# %%
#Post data analysis, it seems there are three columns that do not adding any value,it can be dropped 
#'instant', 'dteday','casual','registered' - considering Casual + Registereed = cnt

data.drop(['instant','dteday','casual','registered'],axis=1,inplace=True)

# %%
data.head(10)
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
# 5       1   0     1        0        4           1           1   8.378268
# 6       1   0     1        0        5           1           2   8.057402
# 7       1   0     1        0        6           0           2   6.765000
# 8       1   0     1        0        0           0           1   5.671653
# 9       1   0     1        0        1           1           1   6.184153
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600
# 5  11.66045  51.8261   6.000868  1606
# 6  10.44195  49.8696  11.304642  1510
# 7   8.11270  53.5833  17.875868   959
# 8   5.80875  43.4167  24.250650   822
# 9   7.54440  48.2917  14.958889  1321

# %%
#verify dropped columns
data.columns
# Out:
# Index(['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'cnt'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    int64
#  1   yr          730 non-null    int64
#  2   mnth        730 non-null    int64
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    int64
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    int64
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   hum         730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 68.6 KB

# %%
#let's check the coorelation
data.corr()
# Out:
#                   season            yr          mnth   holiday   weekday  \
# season      1.000000e+00 -3.272230e-16  8.310321e-01 -0.010868 -0.003081
# yr         -3.272230e-16  1.000000e+00 -5.149955e-16  0.008195 -0.005466
# mnth        8.310321e-01 -5.149955e-16  1.000000e+00  0.018905  0.009523
# holiday    -1.086804e-02  8.195345e-03  1.890483e-02  1.000000 -0.101962
# weekday    -3.081198e-03 -5.466369e-03  9.522969e-03 -0.101962  1.000000
# workingday  1.376178e-02 -2.945396e-03 -4.687953e-03 -0.252948  0.035800
# weathersit  2.130636e-02 -5.032247e-02  4.561335e-02 -0.034395  0.031112
# temp        3.333607e-01  4.878919e-02  2.190833e-01 -0.028764 -0.000168
# atemp       3.420139e-01  4.721519e-02  2.264302e-01 -0.032703 -0.007539
# hum         2.082196e-01 -1.125471e-01  2.249368e-01 -0.015662 -0.052290
# windspeed  -2.296069e-01 -1.162435e-02 -2.080131e-01  0.006257  0.014283
# cnt         4.045838e-01  5.697285e-01  2.781909e-01 -0.068764  0.067534
#
#             workingday  weathersit      temp     atemp       hum  windspeed  \
# season        0.013762    0.021306  0.333361  0.342014  0.208220  -0.229607
# yr           -0.002945   -0.050322  0.048789  0.047215 -0.112547  -0.011624
# mnth         -0.004688    0.045613  0.219083  0.226430  0.224937  -0.208013
# holiday      -0.252948   -0.034395 -0.028764 -0.032703 -0.015662   0.006257
# weekday       0.035800    0.031112 -0.000168 -0.007539 -0.052290   0.014283
# workingday    1.000000    0.060236  0.053470  0.052940  0.023202  -0.018666
# weathersit    0.060236    1.000000 -0.119503 -0.120559  0.590277   0.039769
# temp          0.053470   -0.119503  1.000000  0.991696  0.128565  -0.158186
# atemp         0.052940   -0.120559  0.991696  1.000000  0.141512  -0.183876
# hum           0.023202    0.590277  0.128565  0.141512  1.000000  -0.248506
# windspeed    -0.018666    0.039769 -0.158186 -0.183876 -0.248506   1.000000
# cnt           0.062542   -0.295929  0.627044  0.630685 -0.098543  -0.235132
#
#                  cnt
# season      0.404584
# yr          0.569728
# mnth        0.278191
# holiday    -0.068764
# weekday     0.067534
# workingday  0.062542
# weathersit -0.295929
# temp        0.627044
# atemp       0.630685
# hum        -0.098543
# windspeed  -0.235132
# cnt         1.000000

# %%
#Check null values
data.isnull().sum()
# Out:
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# cnt           0
# dtype: int64

# %%
#let's analyze the data to see if any duplicates available
data.nunique()
# Out:
# season          4
# yr              2
# mnth           12
# holiday         2
# weekday         7
# workingday      2
# weathersit      3
# temp          498
# atemp         689
# hum           594
# windspeed     649
# cnt           695
# dtype: int64

# %%
# let's check the linear relationship using pairplot of numerical variables
plt.figure(figsize = (15,30))
sns.pairplot(data=data,vars=['cnt', 'temp', 'atemp', 'hum','windspeed'])
plt.show()

# %%
# Evident that there is alinear relationship between TEMP and ATEMP

# %%
#let's drawheamap for finding co-relation between numerical variable

numerical_cols = ["temp","atemp","hum","windspeed","cnt"]
plt.figure(figsize=(8,9))
plt.title("Numerical columns co-orelation")
sns.heatmap(data[numerical_cols].corr(),annot= True,cmap="BuGn")
plt.show()

# %%
#Here we see that temp and atemp has correlation more than .99 means almost 
#1 (highly correlated) and atemp seems to be derived from temp so atemp field can be dropped here only

# %% [markdown]
# # Draw Heatmap of correlation between variables

# %%
plt.figure(figsize=(18,8))
sns.heatmap(data.corr(),annot=True, cmap='YlGnBu' )
plt.show()

# %%
# Since temp, atemp has a stronger co-relation, let's delete

# %%
# let's check the categorical variables box plot to see the demands

plt.figure(figsize=(18,10))

plt.subplot(2,3,1)
sns.boxplot(x='season',y='cnt',data=data)

plt.subplot(2,3,2)
sns.boxplot(x='yr',y='cnt',data=data)

plt.subplot(2,3,3)
sns.boxplot(x='mnth',y='cnt',data=data)

plt.subplot(2,3,4)
sns.boxplot(x='weekday',y='cnt',data=data)

plt.subplot(2,3,5)
sns.boxplot(x='workingday',y='cnt',data=data)

plt.subplot(2,3,6)
sns.boxplot(x='weathersit',y='cnt',data=data)
# Out:
# <Axes: xlabel='weathersit', ylabel='cnt'>

# %%
# after anlalyzing above box plots, here are some of the observations
#1 - Demand goes up during fall season
#2 - Demand will go up next year
#3 -  Sept month has got the highest denand
#4 -  Cann't really conclude much looking at weekday boxplot
#5 -   Demand slighly less duinrg working days
#6 - When the weather is good, demand goes up, and vice-versa if weather is bad

# %%
data.season.replace({1:"spring", 2:"summer", 3:"fall", 4:"winter"},inplace = True)

data.weathersit.replace({1:'good',2:'moderate',3:'bad',4:'severe'},inplace = True)

data.mnth = data.mnth.replace({1: 'jan',2: 'feb',3: 'mar',4: 'apr',5: 'may',6: 'jun',
                  7: 'jul',8: 'aug',9: 'sept',10: 'oct',11: 'nov',12: 'dec'})

data.weekday = data.weekday.replace({0: 'sun',1: 'mon',2: 'tue',3: 'wed',4: 'thu',5: 'fri',6: 'sat'})
data.head()
# Out:
#    season  yr mnth  holiday weekday  workingday weathersit       temp  \
# 0  spring   0  jan        0     sat           0   moderate  14.110847
# 1  spring   0  jan        0     sun           0   moderate  14.902598
# 2  spring   0  jan        0     mon           1       good   8.050924
# 3  spring   0  jan        0     tue           1       good   8.200000
# 4  spring   0  jan        0     wed           1       good   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %%
# Now let's start preparing for Linear Regression model, let's create the dummy variables first 
data = pd.get_dummies(data=data,columns=["season","mnth","weekday"],drop_first=True)
data= pd.get_dummies(data=data,columns=["weathersit"])

# %%
data.columns
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'atemp', 'hum', 'windspeed',
#        'cnt', 'season_spring', 'season_summer', 'season_winter', 'mnth_aug',
#        'mnth_dec', 'mnth_feb', 'mnth_jan', 'mnth_jul', 'mnth_jun', 'mnth_mar',
#        'mnth_may', 'mnth_nov', 'mnth_oct', 'mnth_sept', 'weekday_mon',
#        'weekday_sat', 'weekday_sun', 'weekday_thu', 'weekday_tue',
#        'weekday_wed', 'weathersit_bad', 'weathersit_good',
#        'weathersit_moderate'],
#       dtype='object')

# %%
data.shape
# Out:
# (730, 31)

# %%
# Now let's seperate out the train & test data for futher analysis and model setup

# Split the data for training & testing, normally we follow 70:30 rule
X_train, X_test = train_test_split(data, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
#let's check the shape distribution as per 70.30 rule
print(X_train.shape)
print(X_test.shape)
# Out:
# (510, 31)
# (219, 31)

# %%
# Scale to fit
num_vars = ['temp','atemp','hum','windspeed','cnt']

#Use Normalized scaler to scale
scaler = MinMaxScaler()

#Fit and transform training set only
X_train[num_vars] = scaler.fit_transform(X_train[num_vars])

# %%
X_train.describe()
# Out:
#                yr     holiday  workingday        temp       atemp         hum  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.507843    0.025490    0.676471    0.537262    0.512989    0.650369
# std      0.500429    0.157763    0.468282    0.225844    0.212385    0.145882
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.339853    0.332086    0.538643
# 50%      1.000000    0.000000    1.000000    0.540519    0.526811    0.653714
# 75%      1.000000    0.000000    1.000000    0.735215    0.688457    0.754830
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         windspeed         cnt
# count  510.000000  510.000000
# mean     0.320768    0.513620
# std      0.169797    0.224593
# min      0.000000    0.000000
# 25%      0.199179    0.356420
# 50%      0.296763    0.518638
# 75%      0.414447    0.684710
# max      1.000000    1.000000

# %%
#After fitting the scalar, check the max = 1 above
X_test
# Out:
#      yr  holiday  workingday       temp     atemp      hum  windspeed   cnt  \
# 184   0        1           0  29.793347  33.27085  63.7917   5.459106  6043
# 535   1        0           1  32.082500  36.04875  59.2083   7.625404  6211
# 299   0        0           1  19.270000  22.85230  81.2917  13.250121  2659
# 221   0        0           1  31.433347  34.24915  42.4167  13.417286  4780
# 152   0        0           1  29.315000  32.19710  30.5000  19.583229  4968
# ..   ..      ...         ...        ...       ...      ...        ...   ...
# 400   1        0           0  10.899153  13.22605  68.7917  11.791732  2947
# 702   1        0           1  19.509153  23.45270  73.3750  11.666643  6606
# 127   0        0           0  21.661653  25.94665  63.1667   5.000712  4333
# 640   1        0           1  26.957500  29.95665  79.3750   4.458569  7572
# 72    0        0           1  13.333897  16.60000  49.6957   9.174042  2046
#
#      season_spring  season_summer  ...  mnth_sept  weekday_mon  weekday_sat  \
# 184          False          False  ...      False         True        False
# 535          False           True  ...      False        False        False
# 299          False          False  ...      False        False        False
# 221          False          False  ...      False        False        False
# 152          False           True  ...      False        False        False
# ..             ...            ...  ...        ...          ...          ...
# 400           True          False  ...      False        False        False
# 702          False          False  ...      False        False        False
# 127          False           True  ...      False        False        False
# 640          False          False  ...      False        False        False
# 72            True          False  ...      False         True        False
#
#      weekday_sun  weekday_thu  weekday_tue  weekday_wed  weathersit_bad  \
# 184        False        False        False        False           False
# 535        False        False        False         True           False
# 299        False         True        False        False           False
# 221        False        False        False         True           False
# 152        False         True        False        False           False
# ..           ...          ...          ...          ...             ...
# 400         True        False        False        False           False
# 702        False        False         True        False           False
# 127         True        False        False        False           False
# 640        False        False        False         True           False
# 72         False        False        False        False           False
#
#      weathersit_good  weathersit_moderate
# 184            False                 True
# 535             True                False
# 299            False                 True
# 221             True                False
# 152             True                False
# ..               ...                  ...
# 400            False                 True
# 702             True                False
# 127             True                False
# 640            False                 True
# 72              True                False
#
# [219 rows x 31 columns]

# %%
#plt.figure(figsize = (15, 15))  #Checking if the variables are highly correlated
#sns.heatmap(X_train.corr(), annot = True)
#plt.show()
X_train.head(10)
# Out:
#      yr  holiday  workingday      temp     atemp       hum  windspeed  \
# 653   1        0           1  0.509887  0.501133  0.575354   0.300794
# 576   1        0           1  0.815169  0.766351  0.725633   0.264686
# 426   1        0           0  0.442393  0.438975  0.640189   0.255342
# 728   1        0           0  0.245101  0.200348  0.498067   0.663106
# 482   1        0           0  0.395666  0.391735  0.504508   0.188475
# 111   0        0           1  0.345824  0.318819  0.751824   0.380981
# 580   1        0           0  0.914852  0.882350  0.632030   0.462538
# 500   1        0           1  0.719639  0.678508  0.719193   0.172431
# 479   1        0           1  0.520271  0.513565  0.440962   0.164434
# 472   1        0           1  0.503656  0.496135  0.586518   0.270032
#
#           cnt  season_spring  season_summer  ...  mnth_sept  weekday_mon  \
# 653  0.864243          False          False  ...      False        False
# 576  0.827658          False          False  ...      False        False
# 426  0.465255           True          False  ...      False        False
# 728  0.204096           True          False  ...      False        False
# 482  0.482973          False           True  ...      False        False
# 111  0.191095          False           True  ...      False        False
# 580  0.782559          False          False  ...      False        False
# 500  0.851588          False           True  ...      False        False
# 479  0.710308          False           True  ...      False        False
# 472  0.499885          False           True  ...      False        False
#
#      weekday_sat  weekday_sun  weekday_thu  weekday_tue  weekday_wed  \
# 653        False        False        False         True        False
# 576        False        False        False         True        False
# 426         True        False        False        False        False
# 728        False         True        False        False        False
# 482         True        False        False        False        False
# 111        False        False        False        False        False
# 580         True        False        False        False        False
# 500        False        False        False        False         True
# 479        False        False        False        False         True
# 472        False        False        False        False         True
#
#      weathersit_bad  weathersit_good  weathersit_moderate
# 653           False             True                False
# 576           False             True                False
# 426           False            False                 True
# 728           False             True                False
# 482           False            False                 True
# 111           False            False                 True
# 580           False             True                False
# 500           False             True                False
# 479           False             True                False
# 472           False            False                 True
#
# [10 rows x 31 columns]

# %%
# Build a Linear Regression model using SKLearn for RFE
y_train = X_train.pop('cnt')
X_train = X_train
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Model building using RFE

# %%
#Cut down number of features to 15 using automated approach
#rfe = RFE(lr,15)
rfe = RFE(lm, n_features_to_select=15)
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=15)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('holiday', True, 1),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('atemp', False, 8),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('season_spring', False, 15),
#  ('season_summer', True, 1),
#  ('season_winter', True, 1),
#  ('mnth_aug', True, 1),
#  ('mnth_dec', False, 3),
#  ('mnth_feb', False, 5),
#  ('mnth_jan', False, 2),
#  ('mnth_jul', False, 6),
#  ('mnth_jun', False, 11),
#  ('mnth_mar', False, 7),
#  ('mnth_may', False, 16),
#  ('mnth_nov', False, 4),
#  ('mnth_oct', False, 14),
#  ('mnth_sept', True, 1),
#  ('weekday_mon', False, 9),
#  ('weekday_sat', True, 1),
#  ('weekday_sun', True, 1),
#  ('weekday_thu', False, 12),
#  ('weekday_tue', False, 10),
#  ('weekday_wed', False, 13),
#  ('weathersit_bad', True, 1),
#  ('weathersit_good', True, 1),
#  ('weathersit_moderate', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed',
#        'season_summer', 'season_winter', 'mnth_aug', 'mnth_sept',
#        'weekday_sat', 'weekday_sun', 'weathersit_bad', 'weathersit_good',
#        'weathersit_moderate'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['atemp', 'season_spring', 'mnth_dec', 'mnth_feb', 'mnth_jan',
#        'mnth_jul', 'mnth_jun', 'mnth_mar', 'mnth_may', 'mnth_nov', 'mnth_oct',
#        'weekday_mon', 'weekday_thu', 'weekday_tue', 'weekday_wed'],
#       dtype='object')

# %%
#Function to build a model using statsmodel api - Takes the columns to be selected for model as a parameter
def build_model(cols):
    X_train_sm = sm.add_constant(X_train[cols])
    lm = sm.OLS(y_train.astype(float), X_train_sm.astype(float)).fit()
    print(lm.summary())
    return lm

# %%
#Function to calculate VIFs and print them

def get_vif(cols):
    df1 = X_train[cols].astype(float)
    vif = pd.DataFrame()
    vif['Features'] = df1.columns
    vif['VIF'] = [variance_inflation_factor(df1.values, i) for i in range(df1.shape[1])]
    vif['VIF'] = round(vif['VIF'],2)
    print(vif.sort_values(by='VIF',ascending=False))

# %%
cols = ['yr', 'holiday', 'temp', 'atemp', 'hum', 'windspeed', 'season_spring','season_winter', 'mnth_dec', 'mnth_jul', 'mnth_nov', 'mnth_sept','weathersit_bad', 'weathersit_good', 'weathersit_moderate']
build_model(cols)
get_vif(cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.841
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     187.0
# Date:                Mon, 30 Dec 2024   Prob (F-statistic):          2.77e-187
# Time:                        00:28:59   Log-Likelihood:                 507.40
# No. Observations:                 510   AIC:                            -984.8
# Df Residuals:                     495   BIC:                            -921.3
# Df Model:                          14
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1856      0.027      6.932      0.000       0.133       0.238
# yr                      0.2303      0.008     28.178      0.000       0.214       0.246
# holiday                -0.0911      0.026     -3.510      0.000      -0.142      -0.040
# temp                    0.3596      0.130      2.772      0.006       0.105       0.614
# atemp                   0.1107      0.136      0.813      0.416      -0.157       0.378
# hum                    -0.1581      0.038     -4.156      0.000      -0.233      -0.083
# windspeed              -0.1676      0.026     -6.431      0.000      -0.219      -0.116
# season_spring          -0.1111      0.015     -7.368      0.000      -0.141      -0.081
# season_winter           0.0745      0.014      5.222      0.000       0.046       0.103
# mnth_dec               -0.0340      0.017     -2.009      0.045      -0.067      -0.001
# mnth_jul               -0.0771      0.017     -4.467      0.000      -0.111      -0.043
# mnth_nov               -0.0436      0.019     -2.346      0.019      -0.080      -0.007
# mnth_sept               0.0569      0.016      3.634      0.000       0.026       0.088
# weathersit_bad         -0.0840      0.022     -3.790      0.000      -0.128      -0.040
# weathersit_good         0.1632      0.010     16.864      0.000       0.144       0.182
# weathersit_moderate     0.1064      0.012      8.945      0.000       0.083       0.130
# ==============================================================================
# Omnibus:                       64.694   Durbin-Watson:                   1.977
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              168.359
# Skew:                          -0.638   Prob(JB):                     2.76e-37
# Kurtosis:                       5.509   Cond. No.                     4.61e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.32e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                Features    VIF
# 2                  temp  52.96
# 3                 atemp  51.52
# 13      weathersit_good  38.55
# 14  weathersit_moderate  26.70
# 12       weathersit_bad   3.74
# 6         season_spring   2.59
# 7         season_winter   2.36
# 4                   hum   1.90
# 10             mnth_nov   1.69
# 8              mnth_dec   1.37
# 9              mnth_jul   1.30
# 5             windspeed   1.21
# 11            mnth_sept   1.12
# 0                    yr   1.03
# 1               holiday   1.03

# %%
#Model 1 analysis
# let's remove holiday as it has negative cofficient & high p value
cols = ['yr','temp', 'atemp', 'hum', 'windspeed', 'season_spring','season_winter', 'mnth_dec', 'mnth_jul', 'mnth_nov', 'mnth_sept','weathersit_bad', 'weathersit_good', 'weathersit_moderate']
build_model(cols)
get_vif(cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.837
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     196.0
# Date:                Mon, 30 Dec 2024   Prob (F-statistic):          8.30e-186
# Time:                        00:28:59   Log-Likelihood:                 501.13
# No. Observations:                 510   AIC:                            -974.3
# Df Residuals:                     496   BIC:                            -915.0
# Df Model:                          13
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1870      0.027      6.909      0.000       0.134       0.240
# yr                      0.2306      0.008     27.906      0.000       0.214       0.247
# temp                    0.3415      0.131      2.605      0.009       0.084       0.599
# atemp                   0.1291      0.137      0.939      0.348      -0.141       0.399
# hum                    -0.1596      0.038     -4.150      0.000      -0.235      -0.084
# windspeed              -0.1683      0.026     -6.386      0.000      -0.220      -0.117
# season_spring          -0.1143      0.015     -7.511      0.000      -0.144      -0.084
# season_winter           0.0742      0.014      5.143      0.000       0.046       0.103
# mnth_dec               -0.0347      0.017     -2.027      0.043      -0.068      -0.001
# mnth_jul               -0.0760      0.017     -4.356      0.000      -0.110      -0.042
# mnth_nov               -0.0513      0.019     -2.748      0.006      -0.088      -0.015
# mnth_sept               0.0530      0.016      3.357      0.001       0.022       0.084
# weathersit_bad         -0.0815      0.022     -3.636      0.000      -0.126      -0.037
# weathersit_good         0.1619      0.010     16.550      0.000       0.143       0.181
# weathersit_moderate     0.1067      0.012      8.869      0.000       0.083       0.130
# ==============================================================================
# Omnibus:                       74.995   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              207.125
# Skew:                          -0.718   Prob(JB):                     1.06e-45
# Kurtosis:                       5.773   Cond. No.                     4.55e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.49e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                Features    VIF
# 1                  temp  52.88
# 2                 atemp  51.44
# 12      weathersit_good  38.55
# 13  weathersit_moderate  26.69
# 11       weathersit_bad   3.74
# 5         season_spring   2.58
# 6         season_winter   2.36
# 3                   hum   1.90
# 9              mnth_nov   1.66
# 7              mnth_dec   1.37
# 8              mnth_jul   1.30
# 4             windspeed   1.21
# 10            mnth_sept   1.11
# 0                    yr   1.03

# %%
#Model 2 analysis
# let's remove mnth_dec as it has negative cofficient and high p value
cols = ['yr','temp', 'atemp', 'hum', 'windspeed', 'season_spring','season_winter', 'mnth_jul', 'mnth_nov', 'mnth_sept','weathersit_bad', 'weathersit_good', 'weathersit_moderate']
build_model(cols)
get_vif(cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.832
# Method:                 Least Squares   F-statistic:                     210.6
# Date:                Mon, 30 Dec 2024   Prob (F-statistic):          4.29e-186
# Time:                        00:29:00   Log-Likelihood:                 499.03
# No. Observations:                 510   AIC:                            -972.1
# Df Residuals:                     497   BIC:                            -917.0
# Df Model:                          12
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1827      0.027      6.748      0.000       0.129       0.236
# yr                      0.2307      0.008     27.831      0.000       0.214       0.247
# temp                    0.3528      0.131      2.686      0.007       0.095       0.611
# atemp                   0.1322      0.138      0.959      0.338      -0.139       0.403
# hum                    -0.1648      0.039     -4.281      0.000      -0.240      -0.089
# windspeed              -0.1657      0.026     -6.274      0.000      -0.218      -0.114
# season_spring          -0.1127      0.015     -7.394      0.000      -0.143      -0.083
# season_winter           0.0646      0.014      4.726      0.000       0.038       0.091
# mnth_jul               -0.0783      0.017     -4.480      0.000      -0.113      -0.044
# mnth_nov               -0.0376      0.017     -2.155      0.032      -0.072      -0.003
# mnth_sept               0.0554      0.016      3.504      0.000       0.024       0.086
# weathersit_bad         -0.0802      0.022     -3.567      0.000      -0.124      -0.036
# weathersit_good         0.1583      0.010     16.401      0.000       0.139       0.177
# weathersit_moderate     0.1045      0.012      8.695      0.000       0.081       0.128
# ==============================================================================
# Omnibus:                       69.184   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              180.872
# Skew:                          -0.680   Prob(JB):                     5.30e-40
# Kurtosis:                       5.581   Cond. No.                     4.07e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.35e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                Features    VIF
# 1                  temp  52.78
# 2                 atemp  51.44
# 11      weathersit_good  37.96
# 12  weathersit_moderate  26.47
# 10       weathersit_bad   3.74
# 5         season_spring   2.57
# 6         season_winter   2.10
# 3                   hum   1.89
# 8              mnth_nov   1.44
# 7              mnth_jul   1.29
# 4             windspeed   1.21
# 9             mnth_sept   1.11
# 0                    yr   1.03

# %%
#Model 3 analysis
# let's remove humidity as it has negative cofficient and high p value
cols = ['yr','temp', 'atemp', 'windspeed', 'season_spring','season_winter', 'mnth_jul', 'mnth_nov', 'mnth_sept','weathersit_bad', 'weathersit_good', 'weathersit_moderate']
build_model(cols)
get_vif(cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.830
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     220.4
# Date:                Mon, 30 Dec 2024   Prob (F-statistic):          2.20e-183
# Time:                        00:29:00   Log-Likelihood:                 489.80
# No. Observations:                 510   AIC:                            -955.6
# Df Residuals:                     498   BIC:                            -904.8
# Df Model:                          11
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0985      0.019      5.202      0.000       0.061       0.136
# yr                      0.2346      0.008     27.985      0.000       0.218       0.251
# temp                    0.3584      0.134      2.682      0.008       0.096       0.621
# atemp                   0.0931      0.140      0.665      0.506      -0.182       0.368
# windspeed              -0.1357      0.026     -5.240      0.000      -0.187      -0.085
# season_spring          -0.1166      0.015     -7.533      0.000      -0.147      -0.086
# season_winter           0.0540      0.014      3.948      0.000       0.027       0.081
# mnth_jul               -0.0706      0.018     -3.994      0.000      -0.105      -0.036
# mnth_nov               -0.0346      0.018     -1.950      0.052      -0.069       0.000
# mnth_sept               0.0520      0.016      3.242      0.001       0.020       0.084
# weathersit_bad         -0.1295      0.020     -6.603      0.000      -0.168      -0.091
# weathersit_good         0.1542      0.010     15.778      0.000       0.135       0.173
# weathersit_moderate     0.0739      0.010      7.518      0.000       0.055       0.093
# ==============================================================================
# Omnibus:                       71.167   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              181.850
# Skew:                          -0.707   Prob(JB):                     3.25e-40
# Kurtosis:                       5.561   Cond. No.                     3.24e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.28e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                Features    VIF
# 1                  temp  52.77
# 2                 atemp  51.21
# 10      weathersit_good  21.93
# 11  weathersit_moderate  11.68
# 4         season_spring   2.56
# 5         season_winter   2.03
# 9        weathersit_bad   2.02
# 7              mnth_nov   1.44
# 6              mnth_jul   1.28
# 3             windspeed   1.12
# 8             mnth_sept   1.11
# 0                    yr   1.02

# %%
#Model 4 analysis
# let's remove atemp as it has a high p value
cols = ['yr','temp','windspeed', 'season_spring','season_winter', 'mnth_jul', 'mnth_nov', 'mnth_sept','weathersit_bad', 'weathersit_good', 'weathersit_moderate']
build_model(cols)
get_vif(cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.826
# Method:                 Least Squares   F-statistic:                     242.7
# Date:                Mon, 30 Dec 2024   Prob (F-statistic):          1.72e-184
# Time:                        00:29:01   Log-Likelihood:                 489.57
# No. Observations:                 510   AIC:                            -957.1
# Df Residuals:                     499   BIC:                            -910.6
# Df Model:                          10
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1000      0.019      5.320      0.000       0.063       0.137
# yr                      0.2345      0.008     27.994      0.000       0.218       0.251
# temp                    0.4448      0.031     14.293      0.000       0.384       0.506
# windspeed              -0.1390      0.025     -5.464      0.000      -0.189      -0.089
# season_spring          -0.1168      0.015     -7.547      0.000      -0.147      -0.086
# season_winter           0.0549      0.014      4.030      0.000       0.028       0.082
# mnth_jul               -0.0707      0.018     -4.004      0.000      -0.105      -0.036
# mnth_nov               -0.0349      0.018     -1.966      0.050      -0.070   -2.95e-05
# mnth_sept               0.0519      0.016      3.233      0.001       0.020       0.083
# weathersit_bad         -0.1297      0.020     -6.615      0.000      -0.168      -0.091
# weathersit_good         0.1550      0.010     15.996      0.000       0.136       0.174
# weathersit_moderate     0.0748      0.010      7.669      0.000       0.056       0.094
# ==============================================================================
# Omnibus:                       69.810   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              178.630
# Skew:                          -0.693   Prob(JB):                     1.63e-39
# Kurtosis:                       5.546   Cond. No.                     4.00e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.5e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#                Features    VIF
# 9       weathersit_good  21.50
# 10  weathersit_moderate  11.44
# 1                  temp   2.87
# 3         season_spring   2.56
# 4         season_winter   2.01
# 8        weathersit_bad   2.01
# 6              mnth_nov   1.44
# 5              mnth_jul   1.28
# 7             mnth_sept   1.11
# 2             windspeed   1.08
# 0                    yr   1.02

# %%
#Model 5 analysis

# let's remove month_sept as it has -ve cofficent and high pvalue
cols = ['yr','temp','windspeed', 'season_spring','season_winter', 'mnth_jul', 'mnth_nov', 'weathersit_bad', 'weathersit_good', 'weathersit_moderate']
build_model(cols)
get_vif(cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.826
# Model:                            OLS   Adj. R-squared:                  0.823
# Method:                 Least Squares   F-statistic:                     263.5
# Date:                Mon, 30 Dec 2024   Prob (F-statistic):          1.78e-183
# Time:                        00:29:01   Log-Likelihood:                 484.28
# No. Observations:                 510   AIC:                            -948.6
# Df Residuals:                     500   BIC:                            -906.2
# Df Model:                           9
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.1010      0.019      5.321      0.000       0.064       0.138
# yr                      0.2340      0.008     27.675      0.000       0.217       0.251
# temp                    0.4600      0.031     14.813      0.000       0.399       0.521
# windspeed              -0.1461      0.026     -5.713      0.000      -0.196      -0.096
# season_spring          -0.1182      0.016     -7.574      0.000      -0.149      -0.088
# season_winter           0.0554      0.014      4.028      0.000       0.028       0.082
# mnth_jul               -0.0813      0.018     -4.638      0.000      -0.116      -0.047
# mnth_nov               -0.0388      0.018     -2.169      0.031      -0.074      -0.004
# weathersit_bad         -0.1270      0.020     -6.421      0.000      -0.166      -0.088
# weathersit_good         0.1534      0.010     15.704      0.000       0.134       0.173
# weathersit_moderate     0.0745      0.010      7.575      0.000       0.055       0.094
# ==============================================================================
# Omnibus:                       67.814   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.818
# Skew:                          -0.668   Prob(JB):                     4.02e-39
# Kurtosis:                       5.557   Cond. No.                     3.58e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.32e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#               Features    VIF
# 8      weathersit_good  21.49
# 9  weathersit_moderate  11.44
# 1                 temp   2.80
# 3        season_spring   2.56
# 4        season_winter   2.01
# 7       weathersit_bad   2.01
# 6             mnth_nov   1.43
# 5             mnth_jul   1.24
# 2            windspeed   1.07
# 0                   yr   1.02

# %%
#Model 6 analysis

# let's remove month_nov as it has -ve cofficent and high pvalue
cols = ['yr','temp','windspeed', 'season_spring','season_winter', 'mnth_jul', 'weathersit_bad', 'weathersit_good', 'weathersit_moderate']
build_model(cols)
get_vif(cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     293.7
# Date:                Mon, 30 Dec 2024   Prob (F-statistic):          1.04e-183
# Time:                        00:29:01   Log-Likelihood:                 481.89
# No. Observations:                 510   AIC:                            -945.8
# Df Residuals:                     501   BIC:                            -907.7
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0980      0.019      5.158      0.000       0.061       0.135
# yr                      0.2339      0.008     27.568      0.000       0.217       0.251
# temp                    0.4688      0.031     15.173      0.000       0.408       0.530
# windspeed              -0.1492      0.026     -5.823      0.000      -0.200      -0.099
# season_spring          -0.1148      0.016     -7.363      0.000      -0.145      -0.084
# season_winter           0.0437      0.013      3.442      0.001       0.019       0.069
# mnth_jul               -0.0829      0.018     -4.720      0.000      -0.117      -0.048
# weathersit_bad         -0.1263      0.020     -6.365      0.000      -0.165      -0.087
# weathersit_good         0.1511      0.010     15.504      0.000       0.132       0.170
# weathersit_moderate     0.0732      0.010      7.426      0.000       0.054       0.093
# ==============================================================================
# Omnibus:                       66.438   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.765
# Skew:                          -0.653   Prob(JB):                     1.85e-38
# Kurtosis:                       5.543   Cond. No.                     3.49e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.83e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#               Features    VIF
# 7      weathersit_good  21.28
# 8  weathersit_moderate  11.36
# 1                 temp   2.75
# 3        season_spring   2.53
# 6       weathersit_bad   2.01
# 4        season_winter   1.71
# 5             mnth_jul   1.23
# 2            windspeed   1.07
# 0                   yr   1.02

# %%
#Model 7 analysis
# let's remove weathersite_good as it has a very high VIF
cols = ['yr','temp','windspeed', 'season_spring','season_winter', 'mnth_jul', 'weathersit_bad',  'weathersit_moderate']
build_model(cols)
get_vif(cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.824
# Model:                            OLS   Adj. R-squared:                  0.821
# Method:                 Least Squares   F-statistic:                     293.7
# Date:                Mon, 30 Dec 2024   Prob (F-statistic):          1.04e-183
# Time:                        00:29:01   Log-Likelihood:                 481.89
# No. Observations:                 510   AIC:                            -945.8
# Df Residuals:                     501   BIC:                            -907.7
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.2491      0.024     10.177      0.000       0.201       0.297
# yr                      0.2339      0.008     27.568      0.000       0.217       0.251
# temp                    0.4688      0.031     15.173      0.000       0.408       0.530
# windspeed              -0.1492      0.026     -5.823      0.000      -0.200      -0.099
# season_spring          -0.1148      0.016     -7.363      0.000      -0.145      -0.084
# season_winter           0.0437      0.013      3.442      0.001       0.019       0.069
# mnth_jul               -0.0829      0.018     -4.720      0.000      -0.117      -0.048
# weathersit_bad         -0.2774      0.025    -10.911      0.000      -0.327      -0.227
# weathersit_moderate    -0.0779      0.009     -8.637      0.000      -0.096      -0.060
# ==============================================================================
# Omnibus:                       66.438   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.765
# Skew:                          -0.653   Prob(JB):                     1.85e-38
# Kurtosis:                       5.543   Cond. No.                         13.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#               Features   VIF
# 1                 temp  4.19
# 2            windspeed  3.95
# 0                   yr  2.06
# 3        season_spring  1.63
# 7  weathersit_moderate  1.51
# 4        season_winter  1.38
# 5             mnth_jul  1.31
# 6       weathersit_bad  1.08

# %%
## Conclusion
# P Value is close to 0.0 for all the features mostly 
# Not a big between R-squared and Adjusted R-squared values, meaning no more feature elimination required 
# Within the range VIF 
# Hence, we can say that this model can be accepted

# %%
plt.figure(figsize = (15, 15))  #Checking if the variables are highly correlated
sns.heatmap(X_train.corr(), annot = True)
plt.show()

# %%
#Build a model with all columns to select features automatically
def build_model_sk(X,y):
    lr1 = LinearRegression()
    lr1.fit(X,y)
    return lr1

# %%
#Let us build the finalmodel using sklearn
#Build a model with above columns
final_col = ['yr','temp','windspeed', 'season_spring','season_winter', 'mnth_jul', 'weathersit_bad',  'weathersit_moderate']

lr = build_model_sk(X_train[final_col],y_train)
print(lr.intercept_,lr.coef_)
# Out:
# 0.2490590107341416 [ 0.23392759  0.46883372 -0.14924682 -0.11475327  0.04369545 -0.08294674
#  -0.27739952 -0.07789715]

# %%
# Model Evaluation:
# Since we have created the model, let's begin with residual analysis
y_train_pred = lr.predict(X_train[final_col])

# %%
res =  y_train - y_train_pred
sns.distplot(res)
# Out:
# <Axes: xlabel='cnt', ylabel='Density'>

# %%
#Prediction & evaluation based on test set

# %%
#Scale to fit
num_vars = ['temp','atemp','hum','windspeed','cnt']
X_test[num_vars] = scaler.transform(X_test[num_vars])

# %%
#cols from our final model
final_col = ['yr','temp','windspeed', 'season_spring','season_winter', 'mnth_jul', 'weathersit_bad',  'weathersit_moderate']
y_test_pred = lr.predict(X_test[final_col])

# %%
#r2_score(y_test,y_test_pred)

# %%
#conclusion
# focus or expand more duirng spring season, & next year will be more demand of bikesharing 
# less bokking during bad weather like too much cold or raining
